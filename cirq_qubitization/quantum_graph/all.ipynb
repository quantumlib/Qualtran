# %%
import cirq
import numpy as np
import cirq_qubitization
import cirq_qubitization.testing as cq_testing
from cirq_qubitization.jupyter_tools import display_gate_and_compilation
from typing import *
from pprint import pprint

# %%
from cirq_qubitization.quantum_graph.graphviz import \
    PortGraphDrawer, SimplestGraphDrawer
from IPython.display import SVG

# %%
from cirq_qubitization.quantum_graph.examples import *
from cirq_qubitization.quantum_graph.util_bloqs import *

# %%
arr = np.asarray(Split(3))
arr
# Out:
# array(Split(n=3), dtype=object)

# %%
arr[tuple()]
# Out:
# Split(n=3)

# %%
bloq = Split(3)
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = Join((1,1,1))
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = FirstAndRest(50)
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = SplitJoin(50)
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = And()
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = MultiAnd((1,1,1,1))
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())

# %%
bloq = MultiAnd((1,1,1,1)).decompose_bloq()
gd = PortGraphDrawer(bloq)
#print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
