# %%
import cirq
import numpy as np
import cirq_qubitization
import cirq_qubitization.testing as cq_testing
from cirq_qubitization.jupyter_tools import display_gate_and_compilation
from typing import *

# %%
from cirq_qubitization.quantum_graph.graphviz import \
    GraphDrawer, PortGraphDrawer, PrettyGraphDrawer, SimplestGraphDrawer
from IPython.display import SVG

# %%
from cirq_qubitization.quantum_graph.examples import ModMultiply
bloq = ModMultiply(exponent_bitsize=3, x_bitsize=4, mul_constant=123, mod_N = 5)

# %%
gd = SimplestGraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# LeftDangle_exponent;
# LeftDangle_x;
# subgraph cluster_ModMultiply_0 {
# label=ModMultiply_0;
# ModMultiply_0_exponent;
# ModMultiply_0_x;
# }
#
# RightDangle_exponent;
# RightDangle_x;
# LeftDangle_exponent:e -> ModMultiply_0_exponent:w  [fontsize=10, label="(3,)", labelfloat=True];
# LeftDangle_x:e -> ModMultiply_0_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# ModMultiply_0_exponent:e -> RightDangle_exponent:w  [fontsize=10, label="(3,)", labelfloat=True];
# ModMultiply_0_x:e -> RightDangle_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = PortGraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# dang_left_exponent_ [label=exponent, shape=plaintext];
# dang_left_x_ [label=x, shape=plaintext];
# }
#
# subgraph cluster_ModMultiply_0 {
# label=ModMultiply;
# ModMultiply_0_exponent_ [label=exponent, shape=rect, style=rounded];
# ModMultiply_0_x_ [label=x, shape=rect, style=rounded];
# }
#
# subgraph  {
# rank=same;
# dang_right_exponent_ [label=exponent, shape=plaintext];
# dang_right_x_ [label=x, shape=plaintext];
# }
#
# dang_left_exponent_:e -> ModMultiply_0_exponent_:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# dang_left_x_:e -> ModMultiply_0_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# ModMultiply_0_exponent_:e -> dang_right_exponent_:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# ModMultiply_0_x_:e -> dang_right_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = GraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# DanglingT_e_exponent [label=exponent, shape=plaintext];
# DanglingT_e_x [label=x, shape=plaintext];
# }
#
# ModMultiply_0 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >ModMultiply_0</td></tr><TR><TD  port="exponent">exponent</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# subgraph  {
# rank=same;
# DanglingT_w_exponent [label=exponent, shape=plaintext];
# DanglingT_w_x [label=x, shape=plaintext];
# }
#
# DanglingT_e_exponent:e -> ModMultiply_0:exponent:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# DanglingT_e_x:e -> ModMultiply_0:x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# ModMultiply_0:exponent_r:e -> DanglingT_w_exponent:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# ModMultiply_0:x_r:e -> DanglingT_w_x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = PrettyGraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# DanglingT_e_exponent [label=exponent, shape=plaintext];
# DanglingT_e_x [label=x, shape=plaintext];
# }
#
# ModMultiply_0 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ><font point-size="10">ModMult</font></td></tr><TR><TD  port="exponent">exponent</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# subgraph  {
# rank=same;
# DanglingT_w_exponent [label=exponent, shape=plaintext];
# DanglingT_w_x [label=x, shape=plaintext];
# }
#
# DanglingT_e_exponent:e -> ModMultiply_0:exponent:w  [arrowhead=none];
# DanglingT_e_x:e -> ModMultiply_0:x:w  [arrowhead=none];
# ModMultiply_0:exponent_r:e -> DanglingT_w_exponent:w  [arrowhead=none];
# ModMultiply_0:x_r:e -> DanglingT_w_x:w  [arrowhead=none];
# }

# %%
cbloq = bloq.decompose_bloq()
gd = SimplestGraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# LeftDangle_exponent;
# LeftDangle_x;
# subgraph cluster_Join_4 {
# label=Join_4;
# Join_4_jjj;
# Join_4_jjj;
# }
#
# subgraph cluster_SingleControlModMultiply_3 {
# label=SingleControlModMultiply_3;
# SingleControlModMultiply_3_control;
# SingleControlModMultiply_3_x;
# }
#
# subgraph cluster_Split_0 {
# label=Split_0;
# Split_0_sss;
# Split_0_sss;
# }
#
# subgraph cluster_SingleControlModMultiply_2 {
# label=SingleControlModMultiply_2;
# SingleControlModMultiply_2_control;
# SingleControlModMultiply_2_x;
# }
#
# subgraph cluster_SingleControlModMultiply_1 {
# label=SingleControlModMultiply_1;
# SingleControlModMultiply_1_control;
# SingleControlModMultiply_1_x;
# }
#
# RightDangle_exponent;
# RightDangle_x;
# LeftDangle_exponent:e -> Split_0_sss:w  [fontsize=10, label="(3,)", labelfloat=True];
# Split_0_sss:e -> SingleControlModMultiply_1_control:w  [fontsize=10, label="(1,)", labelfloat=True];
# LeftDangle_x:e -> SingleControlModMultiply_1_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# Split_0_sss:e -> SingleControlModMultiply_2_control:w  [fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_1_x:e -> SingleControlModMultiply_2_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# Split_0_sss:e -> SingleControlModMultiply_3_control:w  [fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2_x:e -> SingleControlModMultiply_3_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# SingleControlModMultiply_1_control:e -> Join_4_jjj:w  [fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2_control:e -> Join_4_jjj:w  [fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_3_control:e -> Join_4_jjj:w  [fontsize=10, label="(1,)", labelfloat=True];
# Join_4_jjj:e -> RightDangle_exponent:w  [fontsize=10, label="(3,)", labelfloat=True];
# SingleControlModMultiply_3_x:e -> RightDangle_x:w  [fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = PortGraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# dang_left_exponent_ [label=exponent, shape=plaintext];
# dang_left_x_ [label=x, shape=plaintext];
# }
#
# subgraph cluster_Join_4 {
# label=Join;
# Join_4_jjj_0 [label="jjj[0]", orientation=-90, shape=house];
# Join_4_jjj_1 [label="jjj[1]", orientation=-90, shape=house];
# Join_4_jjj_2 [label="jjj[2]", orientation=-90, shape=house];
# Join_4_jjj_ [label=jjj, orientation=90, shape=house];
# }
#
# subgraph cluster_SingleControlModMultiply_3 {
# label=SingleControlModMultiply;
# SingleControlModMultiply_3_control_ [label=control, shape=rect, style=rounded];
# SingleControlModMultiply_3_x_ [label=x, shape=rect, style=rounded];
# }
#
# subgraph cluster_Split_0 {
# label=Split;
# Split_0_sss_ [label=sss, orientation=-90, shape=house];
# Split_0_sss_0 [label="sss[0]", orientation=90, shape=house];
# Split_0_sss_1 [label="sss[1]", orientation=90, shape=house];
# Split_0_sss_2 [label="sss[2]", orientation=90, shape=house];
# }
#
# subgraph cluster_SingleControlModMultiply_2 {
# label=SingleControlModMultiply;
# SingleControlModMultiply_2_control_ [label=control, shape=rect, style=rounded];
# SingleControlModMultiply_2_x_ [label=x, shape=rect, style=rounded];
# }
#
# subgraph cluster_SingleControlModMultiply_1 {
# label=SingleControlModMultiply;
# SingleControlModMultiply_1_control_ [label=control, shape=rect, style=rounded];
# SingleControlModMultiply_1_x_ [label=x, shape=rect, style=rounded];
# }
#
# subgraph  {
# rank=same;
# dang_right_exponent_ [label=exponent, shape=plaintext];
# dang_right_x_ [label=x, shape=plaintext];
# }
#
# dang_left_exponent_:e -> Split_0_sss_:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# Split_0_sss_2:e -> SingleControlModMultiply_1_control_:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# dang_left_x_:e -> SingleControlModMultiply_1_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# Split_0_sss_1:e -> SingleControlModMultiply_2_control_:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_1_x_:e -> SingleControlModMultiply_2_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# Split_0_sss_0:e -> SingleControlModMultiply_3_control_:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2_x_:e -> SingleControlModMultiply_3_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# SingleControlModMultiply_1_control_:e -> Join_4_jjj_0:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2_control_:e -> Join_4_jjj_1:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_3_control_:e -> Join_4_jjj_2:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# Join_4_jjj_:e -> dang_right_exponent_:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# SingleControlModMultiply_3_x_:e -> dang_right_x_:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = GraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# DanglingT_e_exponent [label=exponent, shape=plaintext];
# DanglingT_e_x [label=x, shape=plaintext];
# }
#
# Join_4 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >Join_4</td></tr><TR><TD  port="jjj">jjj</TD></TR><TR><TD  port="jjj">jjj</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_3 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >SingleControlModMultiply_3</td></tr><TR><TD  port="control">control</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# Split_0 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >Split_0</td></tr><TR><TD  port="sss">sss</TD></TR><TR><TD  port="sss">sss</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_2 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >SingleControlModMultiply_2</td></tr><TR><TD  port="control">control</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_1 [label=<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="3"><tr><td >SingleControlModMultiply_1</td></tr><TR><TD  port="control">control</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# subgraph  {
# rank=same;
# DanglingT_w_exponent [label=exponent, shape=plaintext];
# DanglingT_w_x [label=x, shape=plaintext];
# }
#
# DanglingT_e_exponent:e -> Split_0:sss:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# Split_0:sss_2_r:e -> SingleControlModMultiply_1:control:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# DanglingT_e_x:e -> SingleControlModMultiply_1:x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# Split_0:sss_1_r:e -> SingleControlModMultiply_2:control:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_1:x_r:e -> SingleControlModMultiply_2:x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# Split_0:sss_0_r:e -> SingleControlModMultiply_3:control:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2:x_r:e -> SingleControlModMultiply_3:x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# SingleControlModMultiply_1:control_r:e -> Join_4:jjj_0:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_2:control_r:e -> Join_4:jjj_1:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# SingleControlModMultiply_3:control_r:e -> Join_4:jjj_2:w  [arrowhead=normal, fontsize=10, label="(1,)", labelfloat=True];
# Join_4:jjj_r:e -> DanglingT_w_exponent:w  [arrowhead=normal, fontsize=10, label="(3,)", labelfloat=True];
# SingleControlModMultiply_3:x_r:e -> DanglingT_w_x:w  [arrowhead=normal, fontsize=10, label="(4,)", labelfloat=True];
# }

# %%
gd = PrettyGraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph qual {
# rankdir=LR;
# subgraph  {
# rank=same;
# DanglingT_e_exponent [label=exponent, shape=plaintext];
# DanglingT_e_x [label=x, shape=plaintext];
# }
#
# Join_4 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ></td></tr><TR><TD  port="jjj">jjj</TD></TR><TR><TD  port="jjj">jjj</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_3 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ><font point-size="10">SingleCtrlMM</font></td></tr><TR><TD  port="control">⬤</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# Split_0 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ></td></tr><TR><TD  port="sss">sss</TD></TR><TR><TD  port="sss">sss</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_2 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ><font point-size="10">SingleCtrlMM</font></td></tr><TR><TD  port="control">⬤</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# SingleControlModMultiply_1 [label=<<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0"><tr><td ><font point-size="10">SingleCtrlMM</font></td></tr><TR><TD  port="control">⬤</TD></TR><TR><TD  port="x">x</TD></TR></TABLE>>, shape=plain];
# subgraph  {
# rank=same;
# DanglingT_w_exponent [label=exponent, shape=plaintext];
# DanglingT_w_x [label=x, shape=plaintext];
# }
#
# DanglingT_e_exponent:e -> Split_0:sss:w  [arrowhead=none];
# Split_0:sss_2_r:e -> SingleControlModMultiply_1:control:w  [arrowhead=none];
# DanglingT_e_x:e -> SingleControlModMultiply_1:x:w  [arrowhead=none];
# Split_0:sss_1_r:e -> SingleControlModMultiply_2:control:w  [arrowhead=none];
# SingleControlModMultiply_1:x_r:e -> SingleControlModMultiply_2:x:w  [arrowhead=none];
# Split_0:sss_0_r:e -> SingleControlModMultiply_3:control:w  [arrowhead=none];
# SingleControlModMultiply_2:x_r:e -> SingleControlModMultiply_3:x:w  [arrowhead=none];
# SingleControlModMultiply_1:control_r:e -> Join_4:jjj_0:w  [arrowhead=none];
# SingleControlModMultiply_2:control_r:e -> Join_4:jjj_1:w  [arrowhead=none];
# SingleControlModMultiply_3:control_r:e -> Join_4:jjj_2:w  [arrowhead=none];
# Join_4:jjj_r:e -> DanglingT_w_exponent:w  [arrowhead=none];
# SingleControlModMultiply_3:x_r:e -> DanglingT_w_x:w  [arrowhead=none];
# }

# %%
display_gate_and_compilation(cq_testing.GateHelper(bloq))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 display_gate_and_compilation(cq_testing.GateHelper(bloq))
#
# File ~/qutran/qutran/cirq_qubitization/jupyter_tools.py:25, in display_gate_and_compilation(g, vertical)
#      22 else:
#      23     box = ipywidgets.HBox([out1, out2])
# ---> 25 out1.append_display_data(svg_circuit(g.circuit, registers=g.r))
#      26 out2.append_display_data(
#      27     svg_circuit(cirq.Circuit(cirq.decompose_once(g.operation)), registers=g.r)
#      28 )
#      30 IPython.display.display(box)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:50, in GateHelper.circuit(self)
#      47 @cached_property
#      48 def circuit(self) -> cirq.Circuit:
#      49     """The `gate` applied to example qubits wrapped in a `cirq.Circuit`."""
# ---> 50     return cirq.Circuit(self.operation)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:45, in GateHelper.operation(self)
#      42 @cached_property
#      43 def operation(self) -> cirq.Operation:
#      44     """The `gate` applied to example qubits."""
# ---> 45     return self.gate.on_registers(**self.quregs)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:35, in GateHelper.quregs(self)
#      32 @cached_property
#      33 def quregs(self) -> Dict[str, List[cirq.Qid]]:
#      34     """A dictionary of named qubits appropriate for the registers for the gate."""
# ---> 35     return self.r.get_named_qubits()
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:30, in GateHelper.r(self)
#      27 @cached_property
#      28 def r(self) -> Registers:
#      29     """The Registers system for the gate."""
# ---> 30     return self.gate.registers
#
# AttributeError: 'ModMultiply' object has no attribute 'registers'

# %%
display_gate_and_compilation(cq_testing.GateHelper(cbloq))
