# %%
import cirq
import numpy as np
import cirq_qubitization
import cirq_qubitization.testing as cq_testing
from cirq_qubitization.jupyter_tools import display_gate_and_compilation
from typing import *
from pprint import pprint

# %%
from cirq_qubitization.quantum_graph.graphviz import \
    PortGraphDrawer, SimplestGraphDrawer
from IPython.display import SVG

# %%
from cirq_qubitization.quantum_graph.examples import MultiCNOTSplit
bloq = MultiCNOTSplit(3)
for cxn in bloq.as_composite_bloq().cxns:
    print(cxn.left, '->', cxn.right)
    print()
# Out:
# Wire(binst=LeftDangle, soq=ThruRegister(name='control', bitsize=1), idx=()) -> Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=ThruRegister(name='control', bitsize=1), idx=())
#
# Wire(binst=LeftDangle, soq=CustomRegister(name='target', bitsize=3, wireshape=(), side=<Side.LEFT: 1>), idx=()) -> Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=CustomRegister(name='target', bitsize=3, wireshape=(), side=<Side.LEFT: 1>), idx=())
#
# Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=ThruRegister(name='control', bitsize=1), idx=()) -> Wire(binst=RightDangle, soq=ThruRegister(name='control', bitsize=1), idx=())
#
# Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(0,)) -> Wire(binst=RightDangle, soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(0,))
#
# Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(1,)) -> Wire(binst=RightDangle, soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(1,))
#
# Wire(binst=BloqInstance(bloq=MultiCNOTSplit(n_targets=3), i=0), soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(2,)) -> Wire(binst=RightDangle, soq=CustomRegister(name='target', bitsize=1, wireshape=(3,), side=<Side.RIGHT: 2>), idx=(2,))

# %%
gd = SimplestGraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# subgraph  {
# rank=same;
# control [label="Wire(binst=LeftDangl\ne, soq=ThruRegister(\nname='control',\nbitsize=1), idx=())"];
# target_G6 [label="Wire(binst=LeftDangl\ne, soq=CustomRegiste\nr(name='target',\nbitsize=3,\nwireshape=(),\nside=<Side.LEFT:\n1>), idx=())"];
# }
#
# subgraph cluster_MultiCNOTSplit {
# label="BloqInstance(bloq=Mu\nltiCNOTSplit(n_targe\nts=3), i=0)";
# subgraph cluster_soqs1 {
# label="";
# control_G3 [label="Wire(binst=BloqInsta\nnce(bloq=MultiCNOTSp\nlit(n_targets=3),\ni=0), soq=ThruRegist\ner(name='control',\nbitsize=1), idx=())"];
# }
#
# subgraph cluster_soqs2 {
# label="";
# target_G1 [label="Wire(binst=BloqInsta\nnce(bloq=MultiCNOTSp\nlit(n_targets=3),\ni=0), soq=CustomRegi\nster(name='target',\nbitsize=3,\nwireshape=(),\nside=<Side.LEFT:\n1>), idx=())"];
# target_G2 [label="Wire(binst=BloqInsta\nnce(bloq=MultiCNOTSp\nlit(n_targets=3),\ni=0), soq=CustomRegi\nster(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(0,))"];
# target_G0 [label="Wire(binst=BloqInsta\nnce(bloq=MultiCNOTSp\nlit(n_targets=3),\ni=0), soq=CustomRegi\nster(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(1,))"];
# target_G7 [label="Wire(binst=BloqInsta\nnce(bloq=MultiCNOTSp\nlit(n_targets=3),\ni=0), soq=CustomRegi\nster(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(2,))"];
# }
#
# }
#
# subgraph  {
# rank=same;
# control_G4 [label="Wire(binst=RightDang\nle, soq=ThruRegister\n(name='control',\nbitsize=1), idx=())"];
# target_G8 [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(0,))"];
# target_G5 [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(1,))"];
# target [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(2,))"];
# }
#
# control:e -> control_G3:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G6:e -> target_G1:w  [fontsize=10, label="(3,)", labelfloat=True];
# control_G3:e -> control_G4:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G2:e -> target_G8:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G0:e -> target_G5:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G7:e -> target:w  [fontsize=10, label="(1,)", labelfloat=True];
# }

# %%
gd = PortGraphDrawer(bloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# subgraph  {
# rank=same;
# control [label=control, shape=plaintext];
# target_G6 [label=target, shape=plaintext];
# }
#
# subgraph cluster_MultiCNOTSplit {
# label=MultiCNOTSplit;
# subgraph cluster_soqs1 {
# label="";
# control_G3 [label=control, shape=rect, style=rounded];
# }
#
# subgraph cluster_soqs2 {
# label="";
# target_G1 [label=target, orientation=-90, shape=house];
# target_G2 [label="target[0]", orientation=90, shape=house];
# target_G0 [label="target[1]", orientation=90, shape=house];
# target_G7 [label="target[2]", orientation=90, shape=house];
# }
#
# }
#
# subgraph  {
# rank=same;
# control_G4 [label=control, shape=plaintext];
# target_G8 [label="target[0]", shape=plaintext];
# target_G5 [label="target[1]", shape=plaintext];
# target [label="target[2]", shape=plaintext];
# }
#
# control:e -> control_G3:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G6:e -> target_G1:w  [fontsize=10, label="(3,)", labelfloat=True];
# control_G3:e -> control_G4:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G2:e -> target_G8:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G0:e -> target_G5:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G7:e -> target:w  [fontsize=10, label="(1,)", labelfloat=True];
# }

# %%
cbloq = bloq.decompose_bloq()
gd = SimplestGraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# subgraph  {
# rank=same;
# control_G8 [label="Wire(binst=LeftDangl\ne, soq=ThruRegister(\nname='control',\nbitsize=1), idx=())"];
# target_G2 [label="Wire(binst=LeftDangl\ne, soq=CustomRegiste\nr(name='target',\nbitsize=3,\nwireshape=(),\nside=<Side.LEFT:\n1>), idx=())"];
# }
#
# subgraph cluster_CNOT {
# label="BloqInstance(bloq=<c\nirq_qubitization.qua\nntum_graph.examples.\nCNOT object at\n0x13137ba30>, i=2)";
# subgraph cluster_soqs1 {
# label="";
# control_G10 [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137ba30>, i=2), \nsoq=ThruRegister(nam\ne='control',\nbitsize=1), idx=())"];
# }
#
# subgraph cluster_soqs2 {
# label="";
# target_G14 [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137ba30>, i=2), \nsoq=ThruRegister(nam\ne='target',\nbitsize=1), idx=())"];
# }
#
# }
#
# subgraph cluster_CNOT_G0 {
# label="BloqInstance(bloq=<c\nirq_qubitization.qua\nntum_graph.examples.\nCNOT object at\n0x13137bf40>, i=1)";
# subgraph cluster_soqs3 {
# label="";
# control [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137bf40>, i=1), \nsoq=ThruRegister(nam\ne='control',\nbitsize=1), idx=())"];
# }
#
# subgraph cluster_soqs4 {
# label="";
# target_G3 [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137bf40>, i=1), \nsoq=ThruRegister(nam\ne='target',\nbitsize=1), idx=())"];
# }
#
# }
#
# subgraph cluster_CNOT_G1 {
# label="BloqInstance(bloq=<c\nirq_qubitization.qua\nntum_graph.examples.\nCNOT object at\n0x13137b8b0>, i=3)";
# subgraph cluster_soqs5 {
# label="";
# control_G7 [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137b8b0>, i=3), \nsoq=ThruRegister(nam\ne='control',\nbitsize=1), idx=())"];
# }
#
# subgraph cluster_soqs6 {
# label="";
# target_G9 [label="Wire(binst=BloqInsta\nnce(bloq=<cirq_qubit\nization.quantum_grap\nh.examples.CNOT\nobject at\n0x13137b8b0>, i=3), \nsoq=ThruRegister(nam\ne='target',\nbitsize=1), idx=())"];
# }
#
# }
#
# subgraph cluster_Split {
# label="BloqInstance(bloq=Sp\nlit(n=3), i=0)";
# subgraph cluster_soqs7 {
# label="";
# sss [label="Wire(binst=BloqInsta\nnce(bloq=Split(n=3),\ni=0), soq=CustomRegi\nster(name='sss',\nbitsize=3,\nwireshape=(),\nside=<Side.LEFT:\n1>), idx=())"];
# sss_G5 [label="Wire(binst=BloqInsta\nnce(bloq=Split(n=3),\ni=0), soq=CustomRegi\nster(name='sss',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(0,))"];
# sss_G4 [label="Wire(binst=BloqInsta\nnce(bloq=Split(n=3),\ni=0), soq=CustomRegi\nster(name='sss',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(1,))"];
# sss_G6 [label="Wire(binst=BloqInsta\nnce(bloq=Split(n=3),\ni=0), soq=CustomRegi\nster(name='sss',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(2,))"];
# }
#
# }
#
# subgraph  {
# rank=same;
# control_G11 [label="Wire(binst=RightDang\nle, soq=ThruRegister\n(name='control',\nbitsize=1), idx=())"];
# target_G13 [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(0,))"];
# target_G12 [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(1,))"];
# target [label="Wire(binst=RightDang\nle, soq=CustomRegist\ner(name='target',\nbitsize=1,\nwireshape=(3,),\nside=<Side.RIGHT:\n2>), idx=(2,))"];
# }
#
# target_G2:e -> sss:w  [fontsize=10, label="(3,)", labelfloat=True];
# control_G8:e -> control:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G5:e -> target_G3:w  [fontsize=10, label="(1,)", labelfloat=True];
# control:e -> control_G10:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G4:e -> target_G14:w  [fontsize=10, label="(1,)", labelfloat=True];
# control_G10:e -> control_G7:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G6:e -> target_G9:w  [fontsize=10, label="(1,)", labelfloat=True];
# control_G7:e -> control_G11:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G3:e -> target_G13:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G14:e -> target_G12:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G9:e -> target:w  [fontsize=10, label="(1,)", labelfloat=True];
# }

# %%
gd = PortGraphDrawer(cbloq)
print(gd.graphviz().to_string())
SVG(gd.graphviz().create_svg())
# Out:
# digraph my_graph {
# rankdir=LR;
# subgraph  {
# rank=same;
# control_G8 [label=control, shape=plaintext];
# target_G2 [label=target, shape=plaintext];
# }
#
# subgraph cluster_CNOT {
# label=CNOT;
# subgraph cluster_soqs1 {
# label="";
# control_G10 [label=control, shape=rect, style=rounded];
# }
#
# subgraph cluster_soqs2 {
# label="";
# target_G14 [label=target, shape=rect, style=rounded];
# }
#
# }
#
# subgraph cluster_CNOT_G0 {
# label=CNOT;
# subgraph cluster_soqs3 {
# label="";
# control [label=control, shape=rect, style=rounded];
# }
#
# subgraph cluster_soqs4 {
# label="";
# target_G3 [label=target, shape=rect, style=rounded];
# }
#
# }
#
# subgraph cluster_CNOT_G1 {
# label=CNOT;
# subgraph cluster_soqs5 {
# label="";
# control_G7 [label=control, shape=rect, style=rounded];
# }
#
# subgraph cluster_soqs6 {
# label="";
# target_G9 [label=target, shape=rect, style=rounded];
# }
#
# }
#
# subgraph cluster_Split {
# label=Split;
# subgraph cluster_soqs7 {
# label="";
# sss [label=sss, orientation=-90, shape=house];
# sss_G5 [label="sss[0]", orientation=90, shape=house];
# sss_G4 [label="sss[1]", orientation=90, shape=house];
# sss_G6 [label="sss[2]", orientation=90, shape=house];
# }
#
# }
#
# subgraph  {
# rank=same;
# control_G11 [label=control, shape=plaintext];
# target_G13 [label="target[0]", shape=plaintext];
# target_G12 [label="target[1]", shape=plaintext];
# target [label="target[2]", shape=plaintext];
# }
#
# target_G2:e -> sss:w  [fontsize=10, label="(3,)", labelfloat=True];
# control_G8:e -> control:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G5:e -> target_G3:w  [fontsize=10, label="(1,)", labelfloat=True];
# control:e -> control_G10:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G4:e -> target_G14:w  [fontsize=10, label="(1,)", labelfloat=True];
# control_G10:e -> control_G7:w  [fontsize=10, label="(1,)", labelfloat=True];
# sss_G6:e -> target_G9:w  [fontsize=10, label="(1,)", labelfloat=True];
# control_G7:e -> control_G11:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G3:e -> target_G13:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G14:e -> target_G12:w  [fontsize=10, label="(1,)", labelfloat=True];
# target_G9:e -> target:w  [fontsize=10, label="(1,)", labelfloat=True];
# }

# %%
display_gate_and_compilation(cq_testing.GateHelper(bloq))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 display_gate_and_compilation(cq_testing.GateHelper(bloq))
#
# File ~/qutran/qutran/cirq_qubitization/jupyter_tools.py:25, in display_gate_and_compilation(g, vertical)
#      22 else:
#      23     box = ipywidgets.HBox([out1, out2])
# ---> 25 out1.append_display_data(svg_circuit(g.circuit, registers=g.r))
#      26 out2.append_display_data(
#      27     svg_circuit(cirq.Circuit(cirq.decompose_once(g.operation)), registers=g.r)
#      28 )
#      30 IPython.display.display(box)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:50, in GateHelper.circuit(self)
#      47 @cached_property
#      48 def circuit(self) -> cirq.Circuit:
#      49     """The `gate` applied to example qubits wrapped in a `cirq.Circuit`."""
# ---> 50     return cirq.Circuit(self.operation)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:45, in GateHelper.operation(self)
#      42 @cached_property
#      43 def operation(self) -> cirq.Operation:
#      44     """The `gate` applied to example qubits."""
# ---> 45     return self.gate.on_registers(**self.quregs)
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:35, in GateHelper.quregs(self)
#      32 @cached_property
#      33 def quregs(self) -> Dict[str, List[cirq.Qid]]:
#      34     """A dictionary of named qubits appropriate for the registers for the gate."""
# ---> 35     return self.r.get_named_qubits()
#
# File ~/qutran/py310-cf/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/qutran/qutran/cirq_qubitization/testing.py:30, in GateHelper.r(self)
#      27 @cached_property
#      28 def r(self) -> Registers:
#      29     """The Registers system for the gate."""
# ---> 30     return self.gate.registers
#
# AttributeError: 'MultiCNOTSplit' object has no attribute 'registers'

# %%
display_gate_and_compilation(cq_testing.GateHelper(cbloq))
