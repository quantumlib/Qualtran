# %%
print("hello world")
# Out:
# hello world

# %%
from dev_tools.qualtran_dev_tools.bloq_report_card import get_bloq_report_card, show_bloq_report_card

# %%
df = get_bloq_report_card()
# Out:
# add_k_large
# add_k_small
# add_k_symb
# add_large
# add_oop_large
# add_oop_small
# add_oop_symb
# add_small
# add_symb
# simple_add_k_large
# simple_add_k_small
# bi_qubits_mixer
# eq_k
# greater_than
# gt_k
# leq
# leq_symb
# lt_k
# lt_k_symb
# sq_cmp
# signed_to_twos
# to_contg_index
# multiply_two_reals
# plus_equal_product
# product
# scale_int_by_real
# square
# square_real_number
# sum_of_squares
# bitonic_sort
# cmp_symb
# cnot
# global_phase
# hadamard
# rx
# ry
# rz
# x_pow
# y_pow
# z_pow
# s_gate
# hadamard
# su2_rotation_gate
# t_gate
# cswap_large
# cswap_small
# cswap_symb
# swap_small
# t_gate
# toffoli
# minus_effect
# minus_state
# plus_effect
# plus_state
# int_effect
# int_state
# one_effect
# one_state
# zero_effect
# zero_state
# zgate
# black_box_block_bloq
# black_box_prepare
# black_box_select
# chebyshev_poly
# df_block_encoding
# df_one_body
# indexed_data
# prep_inner
# prep_outer
# prepare_t
# prepare_uv
# prep_mu_proj
# prep_nu_proj
# prep_power_two_proj
# prep_t_proj
# prep_uv_proj
# prep_first_quant
# sel_first_quant
# sel_t_proj
# sel_uv_proj
# prep_first_quant
# sel_first_quant
# select_t
# select_uv
# prep_inner
# prep_outer
# select
# sf_block_encoding
# sf_one_body
# prep_sparse
# sel_sparse
# thc_prep
# thc_uni
# thc_sel
# nr_inv_sqrt
# poly_inv_sqrt
# kinetic_energy
# pair_potential
# potential_energy
# qvr
# hopping_tile
# plaquette
# interaction
# ising_x
# ising_zz
# trott_unitary
# qrom_multi_data
# qrom_multi_dim
# qrom_small
# modexp
# modexp_small
# modexp_symb
# modmul
# modmul_symb
# and_bloq
# multi_and
# c_multi_not
# c_multi_not_symb
# ccpauli
# apply_z_to_odd
# select_pauli_lcu
# /home/linux_environment/miniconda3/envs/quantum/lib/python3.10/site-packages/sympy/core/function.py:297: SymPyDeprecationWarning:
#
# The string fallback in sympify() is deprecated.
#
# To explicitly convert the string form of an object, use
# sympify(str(obj)). To add define sympify behavior on custom
# objects, use sympy.core.sympify.converter or define obj._sympy_
# (see the sympify() docstring).
#
# sympify() performed the string fallback resulting in the following string:
#
# '<function N at 0x7f2b7590bbe0>'
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-sympify-string-fallback
# for details.
#
# This has been deprecated since SymPy version 1.6. It
# will be removed in a future version of SymPy.
#
#   args = list(map(sympify, args))
# lp_resource_state_small
# lp_resource_state_symbolic
# lprs_interim_prep
# textbook_qpe_from_precision_and_delta
# textbook_qpe_from_standard_deviation_eps
# textbook_qpe_small
# textbook_qpe_using_m_bits
# approximate_qft_from_epsilon
# approximate_qft_small
# two_bit_ffft
# walk_op
# reflection
# square_via_phase_gradient
# square_via_zpow_phasing
# qvr_phase_gradient
# qvr_zpow
# c_prep_uniform
# prep_uniform
# state_prep_alias
# state_prep_via_rotation
# approx_cswap_large
# approx_cswap_small
# approx_cswap_symb
# multiplexed_cswap
# swz
# swz_small

# %%
show_bloq_report_card(df)
# Out:
# <style type="text/css">
# #T_18f12_row0_col3, #T_18f12_row0_col4, #T_18f12_row0_col6, #T_18f12_row1_col3, #T_18f12_row1_col4, #T_18f12_row1_col6, #T_18f12_row2_col3, #T_18f12_row2_col6, #T_18f12_row3_col3, #T_18f12_row3_col6, #T_18f12_row4_col3, #T_18f12_row4_col6, #T_18f12_row5_col3, #T_18f12_row5_col6, #T_18f12_row6_col3, #T_18f12_row6_col4, #T_18f12_row6_col6, #T_18f12_row7_col3, #T_18f12_row7_col6, #T_18f12_row8_col3, #T_18f12_row8_col6, #T_18f12_row9_col3, #T_18f12_row9_col6, #T_18f12_row10_col3, #T_18f12_row10_col6, #T_18f12_row11_col3, #T_18f12_row11_col6, #T_18f12_row13_col3, #T_18f12_row13_col4, #T_18f12_row13_col6, #T_18f12_row14_col3, #T_18f12_row14_col6, #T_18f12_row15_col3, #T_18f12_row15_col4, #T_18f12_row15_col6, #T_18f12_row16_col3, #T_18f12_row16_col6, #T_18f12_row18_col3, #T_18f12_row18_col6, #T_18f12_row19_col3, #T_18f12_row19_col4, #T_18f12_row19_col6, #T_18f12_row20_col3, #T_18f12_row20_col4, #T_18f12_row20_col6, #T_18f12_row21_col3, #T_18f12_row21_col6, #T_18f12_row22_col3, #T_18f12_row22_col6, #T_18f12_row23_col3, #T_18f12_row23_col6, #T_18f12_row24_col3, #T_18f12_row24_col6, #T_18f12_row25_col3, #T_18f12_row25_col6, #T_18f12_row26_col3, #T_18f12_row26_col4, #T_18f12_row26_col6, #T_18f12_row27_col3, #T_18f12_row27_col4, #T_18f12_row27_col6, #T_18f12_row28_col3, #T_18f12_row28_col4, #T_18f12_row28_col6, #T_18f12_row29_col3, #T_18f12_row29_col6, #T_18f12_row30_col3, #T_18f12_row30_col6, #T_18f12_row31_col3, #T_18f12_row31_col6, #T_18f12_row32_col3, #T_18f12_row32_col6, #T_18f12_row33_col3, #T_18f12_row33_col6, #T_18f12_row34_col3, #T_18f12_row34_col4, #T_18f12_row34_col5, #T_18f12_row34_col6, #T_18f12_row35_col3, #T_18f12_row35_col4, #T_18f12_row35_col5, #T_18f12_row35_col6, #T_18f12_row36_col3, #T_18f12_row36_col6, #T_18f12_row38_col3, #T_18f12_