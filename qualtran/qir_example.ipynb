# %%
import numpy as np
import pyqir
import qualtran
from qualtran.bloqs.basic_gates import Hadamard, XGate, YGate, ZGate, Rx, Ry, Rz, TGate, TwoBitSwap, CNOT, Toffoli
from qualtran.bloqs.qft.qft_text_book import QFTTextBook
import pyqir
from pyqir import (
    BasicBlock,
    Builder,
    Context,
    Function,
    Linkage,
    Module,
    ModuleFlagBehavior,
)

# %%
import attrs
from typing import Dict
from qualtran import Bloq, BloqBuilder, SoquetT, Signature, Register


@attrs.frozen
class Swap(Bloq):
    n: int

    @property
    def signature(self):
        return Signature.build(x=self.n, y=self.n)

    def build_composite_bloq(
            self, bb: BloqBuilder, *, x: SoquetT, y: SoquetT
    ) -> Dict[str, SoquetT]:
        xs = bb.split(x)
        ys = bb.split(y)

        for i in range(self.n):
            xs[i], ys[i] = bb.add(CNOT(), ctrl=xs[i], target=ys[i])
        return {
            'x': bb.join(xs),
            'y': bb.join(ys),
        }

@attrs.frozen
class ExampleBaseBloq(Bloq):
    @property
    def signature(self):
        return Signature.build(x=1, y=1)

@attrs.frozen
class ExampleHighLevelBloq(Bloq):
    n: int

    @property
    def signature(self):
        return Signature.build(x=self.n, y=self.n)

    def build_composite_bloq(
            self, bb: BloqBuilder, *, x: SoquetT, y: SoquetT
    ) -> Dict[str, SoquetT]:
        xs = bb.split(x)
        ys = bb.split(y)

        for i in range(self.n):
            xs[i], ys[i] = bb.add(ExampleBaseBloq(), x=xs[i], y=ys[i])
        return {
            'x': bb.join(xs),
            'y': bb.join(ys),
        }

@attrs.frozen
class ExampleNonTrivialShapeBloq(Bloq):
    n: int

    @property
    def signature(self):
        return Signature([
            Register('x', bitsize=1, shape=(self.n,)),
            Register('y', bitsize=1, shape=(self.n,)),
        ])

    def build_composite_bloq(
            self, bb: BloqBuilder, *, x: SoquetT, y: SoquetT
    ) -> Dict[str, SoquetT]:
        for i in range(self.n):
            x[i], y[i] = bb.add(ExampleBaseBloq(), x=x[i], y=y[i])
        return {'x': x, 'y': y}

# %%
PYQIR_OP_MAP = {
    # Single-Qubit Clifford Gates
    Hadamard: pyqir._native.h,
    XGate: pyqir._native.x,
    YGate: pyqir._native.y,
    ZGate: pyqir._native.z,
    # Single-Qubit Rotation Gates
    Rx: pyqir._native.rx,
    Ry: pyqir._native.ry,
    Rz: pyqir._native.rz,
    # Single-Qubit Non-Clifford Gates
    TGate: pyqir._native.t,
    # Two-Qubit Gates
    TwoBitSwap: pyqir._native.swap,
    CNOT: pyqir._native.cx,
    # Three-Qubit Gates
    Toffoli: pyqir._native.ccx,
}

# %%
def get_num_qubits_for_bloq(bloq: qualtran.Bloq):
    num_qubits = 0
    for register in bloq.signature.lefts():
        shape = register.shape[0] if len(register.shape) != 0 else 1
        num_qubits += register.bitsize*shape
    return num_qubits

def create_func_for_bloq(bloq: qualtran.Bloq, name, qubit_type, void_type, mod: pyqir.Module):
    num_qubits = get_num_qubits_for_bloq(bloq)
    return Function(
    pyqir.FunctionType(void_type, [qubit_type]*num_qubits),
    Linkage.EXTERNAL,
    name,
    mod
    )

def create_ir_map(bloq: qualtran.Bloq):
    param_counter = 0
    ir_map = {}
    # Loop through all registers in signature
    for register in bloq.signature.lefts():
        shape = register.shape[0] if len(register.shape) != 0 else 1 # get the shape as an int (we are asumming its 1d for simplicity)
        # map the (register_name, index_in_register) to the overall index
        ir_map.update({(register.name, i*register.bitsize + j): param_counter + i*register.bitsize + j for i in range(shape) for j in range(register.bitsize)})
        param_counter += register.bitsize * shape
    return ir_map


def find_ir_for_index(i, ir_map):
    for key, val in ir_map.items():
        if i == val:
            return key
    raise Exception(f"Error in find_ir_for_index: No IR for index {i}")

def get_indexes_from_reg(ir_map, target_reg_name):
    return [ir_map[(reg_name, i)] for (reg_name, i) in ir_map.keys() if reg_name == target_reg_name]

def generate_irs_from_soquet(soq):
    reg_name = soq.reg.name
    starting_index = soq.idx[0] if len(soq.idx) != 0 else 0
    return [(reg_name, starting_index*soq.reg.bitsize + i) for i in range(soq.reg.bitsize)]

def map_soquet_to_params(soq, soq_map, ir_map):
    if isinstance(soq, np.ndarray):
        # renaming to soqs for clarity
        soqs = soq
        return [el for soq in soqs for el in map_soquet_to_params_helper(soq, soq_map, ir_map)]
    return map_soquet_to_params_helper(soq, soq_map, ir_map)

def map_soquet_to_params_helper(soquet, soq_map, ir_map):
    if soquet in soq_map:
        irs = soq_map[soquet]
        return [ir_map[ir] for ir in irs]
    irs = generate_irs_from_soquet(soquet)
    return [ir_map[ir] for ir in irs]

def compile_bloq(bloq: qualtran.Bloq, qubit_type, void_type, module, context, builder, func_dict=dict()):
    func_name = f"{bloq.pretty_name()}_{get_num_qubits_for_bloq(bloq)}"
    if func_name in func_dict:
        return func_dict[func_name]
    bloq_func = create_func_for_bloq(bloq, func_name, qubit_type, void_type, module)
    ir_map = create_ir_map(bloq)
    soq_map = {}

    # It seems like QFTTextBook and PhaseGradientUnitary can be decomposed even though supports_decompose_bloq returns false
    if not bloq.supports_decompose_bloq() and bloq.pretty_name() not in ('QFTTextBook', 'PhaseGradientUnitary'):
        return bloq_func, ir_map

    # Create a block to insert instructions in
    basic_block = BasicBlock(context, "block1", bloq_func)

    # iterate through the DAG of sub bloqs
    for sub_bloq in bloq.decompose_bloq().iter_bloqsoqs():
        bloq_instance, inputs, outputs = sub_bloq
        if bloq_instance.bloq.short_name() == 'Split':
            reg_name = inputs['reg'].reg.name
            for i in range(len(outputs[0])):
                ir = soq_map[inputs['reg']][i] if inputs['reg'] in soq_map else (reg_name, i)
                soq_map[outputs[0][i]] = [ir]
            continue
        if bloq_instance.bloq.short_name() == 'Join':
            irs = [el for soq in inputs['reg'] for el in soq_map[soq]]
            soq_map[outputs[0]] = irs
            continue
        if type(bloq_instance.bloq) in PYQIR_OP_MAP:
            builder.insert_at_end(basic_block)
            param_indexes = [map_soquet_to_params(soquet, soq_map, ir_map)[0] for soquet in inputs.values()] # always one element soquets in elem bloqs
            params = [bloq_func.params[i] for i in param_indexes]
            PYQIR_OP_MAP[type(bloq_instance.bloq)](builder, *params)
        else:
            param_indexes = [None for _ in range(get_num_qubits_for_bloq(bloq_instance.bloq))]

            sub_bloq_func, sub_bloq_ir_map = compile_bloq(bloq_instance.bloq, qubit_type, void_type, module, context, builder, func_dict)
            sub_func_name = f"{bloq_instance.bloq.pretty_name()}_{get_num_qubits_for_bloq(bloq_instance.bloq)}"
            func_dict[sub_func_name] = sub_bloq_func, sub_bloq_ir_map
            for key in inputs.keys():
                caller_param_indices_for_key = map_soquet_to_params(inputs[key], soq_map, ir_map)
                callee_param_indices_for_key = get_indexes_from_reg(sub_bloq_ir_map, key)
                for param_index, qubit_param_index in list(zip(callee_param_indices_for_key, caller_param_indices_for_key)):
                    param_indexes[param_index] = qubit_param_index

            builder.insert_at_end(basic_block)
            params = [bloq_func.params[i] for i in param_indexes]
            builder.call(sub_bloq_func, params)

        # map soquets to ir
        param_index = 0
        for soq in outputs:
            if not isinstance(soq, np.ndarray):
                soq = np.array([soq])
            for single_soq in soq:
                irs = []
                for i in range(single_soq.reg.bitsize):
                    irs.append(find_ir_for_index(param_indexes[param_index], ir_map))
                    param_index+=1
                soq_map[single_soq] = irs

    return bloq_func, ir_map


def convert_qualtran(bloq: qualtran.Bloq):
    context = Context()
    mod = pyqir.qir_module(
        context,
        "Main"
    )
    builder = Builder(context)
    qubit_type = pyqir.qubit_type(context)
    void_type = pyqir.Type.void(context)
    entry = pyqir.entry_point(
            mod, "main", get_num_qubits_for_bloq(bloq), 0
        )
    entry_block = BasicBlock(context, "entry", entry)
    builder.insert_at_end(entry_block)
    qubits = [pyqir.qubit(context, n) for n in range(get_num_qubits_for_bloq(bloq))]
    bloq_func, _ = compile_bloq(bloq, qubit_type, void_type, mod, context, builder)
    builder.insert_at_end(entry_block)
    builder.call(bloq_func, qubits)
    return mod

qft_bloq = QFTTextBook(20)
qft_mod = convert_qualtran(qft_bloq)

# %%
print(qft_mod)
# Out:
# ; ModuleID = 'Main'
# source_filename = "Main"
#
# %Qubit = type opaque
#
# define void @main() #0 {
# entry:
#   call void @QFTTextBook_20(%Qubit* null, %Qubit* inttoptr (i64 1 to %Qubit*), %Qubit* inttoptr (i64 2 to %Qubit*), %Qubit* inttoptr (i64 3 to %Qubit*), %Qubit* inttoptr (i64 4 to %Qubit*), %Qubit* inttoptr (i64 5 to %Qubit*), %Qubit* inttoptr (i64 6 to %Qubit*), %Qubit* inttoptr (i64 7 to %Qubit*), %Qubit* inttoptr (i64 8 to %Qubit*), %Qubit* inttoptr (i64 9 to %Qubit*), %Qubit* inttoptr (i64 10 to %Qubit*), %Qubit* inttoptr (i64 11 to %Qubit*), %Qubit* inttoptr (i64 12 to %Qubit*), %Qubit* inttoptr (i64 13 to %Qubit*), %Qubit* inttoptr (i64 14 to %Qubit*), %Qubit* inttoptr (i64 15 to %Qubit*), %Qubit* inttoptr (i64 16 to %Qubit*), %Qubit* inttoptr (i64 17 to %Qubit*), %Qubit* inttoptr (i64 18 to %Qubit*), %Qubit* inttoptr (i64 19 to %Qubit*))
# }
#
# define void @QFTTextBook_20(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15, %Qubit* %16, %Qubit* %17, %Qubit* %18, %Qubit* %19) {
# block1:
#   call void @cirq.H_1(%Qubit* %0)
#   call void @PhaseGradientUnitary_2(%Qubit* %1, %Qubit* %0)
#   call void @cirq.H_1(%Qubit* %1)
#   call void @PhaseGradientUnitary_3(%Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %2)
#   call void @PhaseGradientUnitary_4(%Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %3)
#   call void @PhaseGradientUnitary_5(%Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %4)
#   call void @PhaseGradientUnitary_6(%Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %5)
#   call void @PhaseGradientUnitary_7(%Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %6)
#   call void @PhaseGradientUnitary_8(%Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %7)
#   call void @PhaseGradientUnitary_9(%Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %8)
#   call void @PhaseGradientUnitary_10(%Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %9)
#   call void @PhaseGradientUnitary_11(%Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %10)
#   call void @PhaseGradientUnitary_12(%Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %11)
#   call void @PhaseGradientUnitary_13(%Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %12)
#   call void @PhaseGradientUnitary_14(%Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %13)
#   call void @PhaseGradientUnitary_15(%Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %14)
#   call void @PhaseGradientUnitary_16(%Qubit* %15, %Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %15)
#   call void @PhaseGradientUnitary_17(%Qubit* %16, %Qubit* %15, %Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %16)
#   call void @PhaseGradientUnitary_18(%Qubit* %17, %Qubit* %16, %Qubit* %15, %Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %17)
#   call void @PhaseGradientUnitary_19(%Qubit* %18, %Qubit* %17, %Qubit* %16, %Qubit* %15, %Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %18)
#   call void @PhaseGradientUnitary_20(%Qubit* %19, %Qubit* %18, %Qubit* %17, %Qubit* %16, %Qubit* %15, %Qubit* %14, %Qubit* %13, %Qubit* %12, %Qubit* %11, %Qubit* %10, %Qubit* %9, %Qubit* %8, %Qubit* %7, %Qubit* %6, %Qubit* %5, %Qubit* %4, %Qubit* %3, %Qubit* %2, %Qubit* %0, %Qubit* %1)
#   call void @cirq.H_1(%Qubit* %19)
#   call void @cirq.SWAP_2(%Qubit* %0, %Qubit* %18)
#   call void @cirq.SWAP_2(%Qubit* %2, %Qubit* %17)
#   call void @cirq.SWAP_2(%Qubit* %3, %Qubit* %16)
#   call void @cirq.SWAP_2(%Qubit* %4, %Qubit* %15)
#   call void @cirq.SWAP_2(%Qubit* %5, %Qubit* %14)
#   call void @cirq.SWAP_2(%Qubit* %6, %Qubit* %13)
#   call void @cirq.SWAP_2(%Qubit* %7, %Qubit* %12)
#   call void @cirq.SWAP_2(%Qubit* %8, %Qubit* %11)
#   call void @cirq.SWAP_2(%Qubit* %9, %Qubit* %10)
#   call void @cirq.SWAP_2(%Qubit* %1, %Qubit* %19)
# }
#
# declare void @cirq.H_1(%Qubit*)
#
# define void @PhaseGradientUnitary_2(%Qubit* %0, %Qubit* %1) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
# }
#
# declare void @"cirq.CZ**0.5_2"(%Qubit*, %Qubit*)
#
# define void @PhaseGradientUnitary_3(%Qubit* %0, %Qubit* %1, %Qubit* %2) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
# }
#
# declare void @"cirq.CZ**0.25_2"(%Qubit*, %Qubit*)
#
# define void @PhaseGradientUnitary_4(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
# }
#
# declare void @cirq.CZPowGate_2(%Qubit*, %Qubit*)
#
# define void @PhaseGradientUnitary_5(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
# }
#
# define void @PhaseGradientUnitary_6(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
# }
#
# define void @PhaseGradientUnitary_7(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
# }
#
# define void @PhaseGradientUnitary_8(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
# }
#
# define void @PhaseGradientUnitary_9(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
# }
#
# define void @PhaseGradientUnitary_10(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
# }
#
# define void @PhaseGradientUnitary_11(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
# }
#
# define void @PhaseGradientUnitary_12(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
# }
#
# define void @PhaseGradientUnitary_13(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
# }
#
# define void @PhaseGradientUnitary_14(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
# }
#
# define void @PhaseGradientUnitary_15(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
# }
#
# define void @PhaseGradientUnitary_16(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %15)
# }
#
# define void @PhaseGradientUnitary_17(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15, %Qubit* %16) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %15)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %16)
# }
#
# define void @PhaseGradientUnitary_18(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15, %Qubit* %16, %Qubit* %17) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %15)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %16)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %17)
# }
#
# define void @PhaseGradientUnitary_19(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15, %Qubit* %16, %Qubit* %17, %Qubit* %18) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %15)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %16)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %17)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %18)
# }
#
# define void @PhaseGradientUnitary_20(%Qubit* %0, %Qubit* %1, %Qubit* %2, %Qubit* %3, %Qubit* %4, %Qubit* %5, %Qubit* %6, %Qubit* %7, %Qubit* %8, %Qubit* %9, %Qubit* %10, %Qubit* %11, %Qubit* %12, %Qubit* %13, %Qubit* %14, %Qubit* %15, %Qubit* %16, %Qubit* %17, %Qubit* %18, %Qubit* %19) {
# block1:
#   call void @"cirq.CZ**0.5_2"(%Qubit* %0, %Qubit* %1)
#   call void @"cirq.CZ**0.25_2"(%Qubit* %0, %Qubit* %2)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %3)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %4)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %5)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %6)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %7)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %8)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %9)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %10)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %11)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %12)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %13)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %14)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %15)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %16)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %17)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %18)
#   call void @cirq.CZPowGate_2(%Qubit* %0, %Qubit* %19)
# }
#
# declare void @cirq.SWAP_2(%Qubit*, %Qubit*)
#
# attributes #0 = { "entry_point" "output_labeling_schema" "qir_profiles"="custom" "required_num_qubits"="20" "required_num_results"="0" }
#
# !llvm.module.flags = !{!0, !1, !2, !3}
#
# !0 = !{i32 1, !"qir_major_version", i32 1}
# !1 = !{i32 7, !"qir_minor_version", i32 0}
# !2 = !{i32 1, !"dynamic_qubit_management", i1 false}
# !3 = !{i32 1, !"dynamic_result_management", i1 false}
