# %% [markdown]
# # Single Factorization

# %%
from qualtran import Bloq, CompositeBloq, BloqBuilder, Signature, Register
from qualtran.drawing import show_bloq
from typing import *
import numpy as np

# %% [markdown]
# ## `SingleFactorization`
# Block encoding of single factorization one-body Hamiltonian.

# %%
from qualtran.bloqs.chemistry.single_factorization import SingleFactorization

bloq = SingleFactorization(10, 20, 8)
show_bloq(bloq.decompose_bloq())
# Out:
# Signature((Register(name='sys', bitsize=10, shape=(), side=<Side.THRU: 3>), Register(name='p', bitsize=5, shape=(), side=<Side.THRU: 3>), Register(name='q', bitsize=5, shape=(), side=<Side.THRU: 3>), Register(name='swap_pq', bitsize=1, shape=(), side=<Side.THRU: 3>), Register(name='alpha', bitsize=1, shape=(), side=<Side.THRU: 3>), Register(name='succ_l', bitsize=1, shape=(), side=<Side.THRU: 3>), Register(name='l_ne_zero', bitsize=1, shape=(), side=<Side.THRU: 3>)))
