# %%
from qualtran.bloqs.data_loading.one_hot_encoding import OneHotEncoding

bloq = OneHotEncoding(binary_bitsize=3)
# Out:
# /Users/samuelkushnir/miniconda3/envs/Qualtran-New/lib/python3.10/site-packages/cotengra/hyperoptimizers/hyper.py:34: UserWarning: Couldn't import `kahypar` - skipping from default hyper optimizer and using basic `labels` method instead.
#   warnings.warn(

# %%
list(list(bloq.decompose_bloq().iter_bloqsoqs())[3][0].bloq.decompose_bloq().iter_bloqsoqs())[0][0]
# Out:
# ---------------------------------------------------------------------------
# DecomposeNotImplementedError              Traceback (most recent call last)
# File ~/Documents/GitHub/Qualtran/qualtran/_infra/gate_with_registers.py:291, in GateWithRegisters.decompose_bloq(self)
#     290 try:
# --> 291     return Bloq.decompose_bloq(self)
#     292 except DecomposeNotImplementedError:
#
# File ~/Documents/GitHub/Qualtran/qualtran/_infra/bloq.py:142, in Bloq.decompose_bloq(self)
#     129 """Decompose this Bloq into its constituent parts contained in a CompositeBloq.
#     130
#     131 Bloq users can call this function to delve into the definition of a Bloq. If you're
#    (...)
#     140         `build_composite_bloq` returns `NotImplemented`.
#     141 """
# --> 142 return _decompose_from_build_composite_bloq(self)
#
# File ~/Documents/GitHub/Qualtran/qualtran/_infra/bloq.py:51, in _decompose_from_build_composite_bloq(bloq)
# ...

# %%
from qualtran.drawing import show_bloq
show_bloq(list(bloq.decompose_bloq().iter_bloqsoqs())[3][0].bloq.decompose_bloq(), type="musical_score")
# show_bloq(bloq.decompose_bloq(), type="musical_score")
